# %% [markdown]
# ### 作業1 :
# 練習使用一個民生物聯網 API，例如空氣、地震等感測站所回傳的紀錄資料。
#            參考資料網址： https://ci.taiwan.gov.tw/dsp/environmental.aspx

# %%
#科技部智慧園區空品測站監測資料 
#Python 讀取API參考資料:https://www.dataquest.io/blog/python-api-tutorial/
import requests
import json

url_Data = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_MOST/v1.0/Datastreams(1)?$expand=Observations,ObservedProperty"
#https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams
response =requests.get(url_Data)
#Check response"
print(response.status_code)
result= json.dumps(response.json(),sort_keys=True,indent = 4)
print(result)
# Out:
# 200
# {
#     "@iot.id": 1,
#     "@iot.selfLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_MOST/v1.0/Datastreams(1)",
#     "Observations": [
#         {
#             "@iot.id": 103717040,
#             "@iot.selfLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_MOST/v1.0/Observations(103717040)",
#             "phenomenonTime": "2020-09-23T08:00:00.000Z",
#             "result": 11,
#             "resultTime": null
#         },
#         {
#             "@iot.id": 103705576,
#             "@iot.selfLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_MOST/v1.0/Observations(103705576)",
#             "phenomenonTime": "2020-09-22T21:00:00.000Z",
#             "result": 10,
#             "resultTime": null
#         },
#         {
#             "@iot.id": 103717332,
#             "@iot.selfLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_MOST/v1.0/Observations(103717332)",
#             "phenomenonTime": "2020-09-23T09:00:00.000Z",
#             "result": 11,
# ...

# %% [markdown]
# ### 作業2 :
# 練習操作 OGC SensorThings API，將環保局測站位置的資料抓取下來，並且觀察下載資料的內容。
#            參考網址：https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things

# %%
# URL for the API
url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things"

# POST the request to the server
response = requests.get(url)
# GET the response from the server and grab the json
data = response.json()
data
# Out:
# {'@iot.count': 9703,
#  '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100',
#  'value': [{'description': '智慧城鄉空品微型感測器-11113765144',
#    '@iot.id': 1,
#    'name': '智慧城鄉空品微型感測器-11113765144',
#    'properties': {'city': '基隆市',
#     'areaType': '一般社區',
#     'isMobile': 'false',
#     'township': '七堵區',
#     'authority': '行政院環境保護署',
#     'isDisplay': 'true',
#     'isOutdoor': 'true',
#     'stationID': '11113765144',
#     'locationId': 'TW020201D0506810',
#     'Description': '廣域SAQ-210',
#     'areaDescription': '七堵區'},
#    '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)',
#    'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/MultiDatastreams',
#    'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams',
# ...

# %%
# Get the amount of data
count = data["@iot.count"]
print(f'The amounts of data equal to {count}')
next_link = data['@iot.nextLink']
print(f'Return the link of data from 100 to 200 {next_link}')
# Out:
# The amounts of data equal to 9703
# Return the link of data from 100 to 200 https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100

# %% [markdown]
# ### 作業3 :
# 依據作業 2 所下載的各個環保局測站感測器的描述資料，進一步點選 Datastreams、Locations，以及 Datastreams 點選進入後，點選 Observations 的 URL，觀察所下載到的資料內容，其中 Observations 內部是否包含個別感測器紀錄的資料。

# %%
# URL for the API
url_loc = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations"
# POST the request to the server
response = requests.get(url_loc)
# GET the response from the server and grab the json
data_loc = response.json()
data_loc
# Out:
# {'@iot.count': 9703,
#  '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations?$skip=100',
#  'value': [{'description': '智慧城鄉空品微型感測器-10050820132',
#    'encodingType': 'application/vnd.geo+json',
#    '@iot.id': 2503,
#    'location': {'type': 'Point', 'coordinates': [120.2526816, 23.043223]},
#    'name': '智慧城鄉空品微型感測器-10050820132',
#    '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations(2503)',
#    'Things@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations(2503)/Things',
#    'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations(2503)/HistoricalLocations'},
#   {'description': '智慧城鄉空品微型感測器-6874688232',
#    'encodingType': 'application/vnd.geo+json',
#    '@iot.id': 2502,
#    'location': {'type': 'Point', 'coordinates': [121.82086, 24.63089]},
#    'name': '智慧城鄉空品微型感測器-6874688232',
# ...

# %%
# URL for the API
url_dataS = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(1)/Observations"
# POST the request to the server
response = requests.get(url_dataS)
# GET the response from the server and grab the json
data_DataStream = response.json()
data_DataStream
# Out:
# {'@iot.count': 125,
#  '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(1)/Observations?$skip=100',
#  'value': [{'@iot.id': 202159542,
#    'phenomenonTime': '2020-12-23T12:07:19.000Z',
#    'result': 5.84,
#    'resultTime': None,
#    '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(202159542)',
#    'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(202159542)/MultiDatastream',
#    'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(202159542)/FeatureOfInterest',
#    'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(202159542)/Datastream'},
#   {'@iot.id': 202093243,
#    'phenomenonTime': '2020-12-23T12:03:19.000Z',
#    'result': 5.85,
#    'resultTime': None,
# ...

# %% [markdown]
# ANS:Observation內包含量測資料
