# %% [markdown]
# ### 作業1：
# 請問 YOLO 訓練前，分別要對哪幾個檔案做設定？

# %% [markdown]
# ANS:範例中只分類三種類別(ben_afflek/nelton_john/jerry_seinfeld)，所以先修改調整訓練用的cfg檔，將class數由5改成3

# %%
from IPython.display import Image
Image(filename="23.jpg")

# %% [markdown]
# 在修改調整模型的設定檔(obj.names和obj.data)，透過echo方式修改類別名稱&類別數

# %%
Image(filename="24.jpg")

# %% [markdown]
# ### 作業2：
# 請問 UNIX 的文字取代工具 sed 在使用時，指定參數 -i 有什麼意義？

# %% [markdown]
# sed 的『 -i 』選項可以直接修改檔案內容，透過 sed 直接修改/取代的功能，甚至不需要使用 vim 去修訂檔案內容。<br />
# 參考資料:<br />
# [sed -i命令詳解及入門攻略](https://www.itread01.com/content/1542849603.html "Title")<br />
# [鳥哥的 Linux 私房菜](http://linux.vbird.org/linux_basic/0330regularex.php "Title")

# %%
Image(filename="25.jpg")

# %%
Image(filename="26.jpg")

# %% [markdown]
# ### 作業3：
# 請問 UNIX 的文字編輯工具 echo 在使用時，指定參數 -e 有什麼意義？

# %% [markdown]
# echo命令常用於在shell中列印shell變量的值，或者直接輸出指定的字符串。關於-e的常用的用法，主要在激活轉義字符。使用-e選項，若字符串中出現以下字符，則特別加以處理，不會將它當成一般文字輸出。
#
# + \a 發出警告聲。
# + \b 刪除前一個字符。
# + \c 最後不加上換行符號。
# + \f 換行但光標仍舊停留在原來的位置。
# + \n 換行且光標移至行首。
# + \r 光標移至行首，但不換行。
# + \t 插入tab。
# + \\ 插入\字符。
#
#
#
# 原文網址：https://kknews.cc/code/98v8k88.html
