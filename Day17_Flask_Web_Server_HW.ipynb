# %% [markdown]
# # 作業：使用 Flask 撰寫一個 Web Server

# %% [markdown]
# # [作業目標]
# * 分別實作接受 Get 和 Post 方法的 api。
# * 使用 Post 完成檔案上傳功能，並提供簡易的上傳畫面。

# %% [markdown]
# ## [作業重點]
#
# * 能充分理解 Get / Post 差異。
# * 使用 Postman 發送 Request，確定功能是否正確。

# %% [markdown]
# # 作業1
# * 實作只接受 Get 發送的 Request，帶入參數 name，將其值回傳。

# %%
from flask import Flask,request
app = Flask(__name__)
@app.route('/',methods = ['GET'])

def index():
    name = request.args.get('name')
    return name

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Jan/2021 09:26:06] "GET /?name=Dave HTTP/1.1" 200 -

# %%
from IPython.display import Image
Image(filename="15.jpg")

# %% [markdown]
# # 作業2
# * 實作只接受 Post 發送的 Request，帶入參數 name，將其值回傳。

# %%
from flask import Flask,request
app = Flask(__name__)
@app.route('/',methods = ['POST'])

def index():
    name = request.form.get('name')
    return 'POST:'+ name

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Jan/2021 09:38:57] "POST /?name=Dave HTTP/1.1" 200 -

# %%
Image(filename="16.jpg")

# %% [markdown]
# # 作業3
# * 使用 Post 實作檔案上傳功能，並有一個簡單的畫面可以操作檔案上傳的動作。

# %%
from flask import Flask,request
app = Flask(__name__)
@app.route('/',methods = ['POST'])

def index():
    files = request.files.getlist('file')
    total = 0
    for f in files:
        total += 1
        f.save(f.filename)
    return 'The number of files uploaded by post:' + str(total)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Jan/2021 09:48:08] "POST / HTTP/1.1" 200 -

# %%
Image(filename="17.jpg")
