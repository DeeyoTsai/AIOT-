# %%
# 引用需要的套件, 若有多個套件要引用，可使用逗號隔開
from flask import Flask, request

app = Flask(__name__)

# 設定網址路由，及接受的 method(預設是 GET)
@app.route('/', methods=['GET'])
def index():
    return "Hello World"
    
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [20/Jan/2021 09:19:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jan/2021 09:19:12] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Jan/2021 09:27:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jan/2021 09:48:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jan/2021 09:48:22] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ### 作業 1
# * 成功執行一個含有 Flask 的 Docker image，並可以連到該 Server
#
# `註： 請將實作結果截圖`

# %%
from IPython.display import Image
Image(filename="13.png")

# %%
Image(filename="14.png")
